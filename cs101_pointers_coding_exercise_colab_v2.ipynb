# %% [markdown]
# <a href="https://colab.research.google.com/github/suye-code/cs101/blob/main/cs101_pointers_coding_exercise_colab_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 101 — Pointillism
#
# ![La_Grande_Jatte_George_Seurat_1884.png](data:image/png;base64,...)
#
# **Instructions**
#
# - Work directly in this notebook.
# - For each part, **edit the C++ code until it works**.
# - Run the `%%writefile` cell first, then run the compile/run cell below it.
# - When finished, submit the **shared Colab URL**.
# - Do not write long explanations unless a section explicitly asks for one line of output interpretation.
#
# **Workflow in Colab**
#
# 1. Edit the starter code in the `%%writefile` cell.
# 2. Run that cell to save the file.
# 3. Run the next cell to compile and execute it.
# 4. Keep going until each program behaves as required.
#
# This exercise is based on the lecture topics:
# - address-of operator `&`
# - pointer variables and dereferencing `*`
# - arrays as function arguments
# - pointer arithmetic
# - re-pointing pointers
# - references vs pointers
# - `nullptr` and common pointer mistakes
#
# *The notebook template was created by OpenAI's ChatGPT. You'll have to take up your grievances with the machine, not with me.*

# %% [markdown]
# ## Learning goals
#
# By the end of this notebook, you should be able to:
#
# 1. print the address of a variable
# 2. declare and initialize pointer variables safely with
# 3. use `*ptr` to read and change a value indirectly
# 4. pass arrays to functions
# 5. use explicit pointer syntax in function parameters
# 6. use basic pointer arithmetic
# 7. re-point a pointer to different variables
# 8. distinguish references from pointers in working code

# %% [markdown]
# ## Colab note
#
# Standard Colab already lets you compile C++ with `g++`, so this notebook uses the simpler pattern:
#
# - `%%writefile file.cpp`
# - `!g++ file.cpp -o file`
# - `!./file`
#
# No installation cell is needed.
#
# For printing, you don't need `printf`, just use `cout` as usual.

# %% [markdown]
# ## Part 1 — Address of a variable
#
# **Task**
#
# Write a program that:
#
# 1. declares an integer variable `x`
# 2. assigns it the value `42`
# 3. prints:
#    - the value of `x`
#    - the size of `x`
#    - the address of `x`

# %%
# %%writefile part1.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   // TODO:
#   // 1. declare x and assign 42
#   // 2. print value of x
#   // 3. print size of x
#   // 4. print address of x
#
#   return 0;
# }

# %%
# !g++ -std=c++17 part1.cpp -o part1
# !./part1

# %% [markdown]
# ## Part 2 — Store an address in a pointer
#
# **Task**
#
# Write a program that:
#
# 1. declares `int x = 42;`
# 2. declares an integer pointer `ptr`
# 3. initializes the pointer with the null pointer
# 4. stores the address of `x` in the pointer
# 5. prints:
#    - the value in `x` using the pointer
#    - the address of `x` using the pointer

# %%
# %%writefile part2.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   int x = 25;
#
#   // TODO:
#   // 1. declare ptr and initialize it with the null pointer
#   // 2. make ptr point to x
#   // 3. print the value in x through ptr
#   // 4. print the address stored in ptr
#
#   return 0;
# }

# %%
# !g++ -std=c++17 part2.cpp -o part2
# !./part2

# %% [markdown]
# ## Part 3 — Change a variable indirectly
#
# **Task**
#
# Write a program that:
#
# 1. declares `int x = 42;`
# 2. makes a pointer point to `x`
# 3. prints the value of `x` directly
# 4. changes `x` to `99` through the pointer
# 5. prints the new value of `x` directly and indirectly (through indirection or dereferencing of a pointer).

# %%
# %%writefile part3.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   int x = 42;
#
#   // TODO:
#   // 1. declare ptr
#   // 2. make ptr point to x
#   // 3. print x directly
#   // 4. change x to 99 through ptr
#   // 5. print x directly and indirectly
#
#   return 0;
# }

# %%
# !g++ -std=c++17 part3.cpp -o part3
# !./part3

# %% [markdown]
# ## Part 4 — Arrays and functions
#
# **Task**
#
# Complete the function `showValues` so that it prints all elements of the array on one line separated by spaces.
#
# Use this array in `main`:
#
# ```cpp
# int numbers[5] = {1,2,3,4,5};
# ```
#
# Then call:
#
# ```cpp
# showValues(numbers, 5);
# ```

# %%
# %%writefile part4.cpp
# #include <iostream>
# using namespace std;
#
# // TODO: write the function prototype showValues
#
# int main() {
#   int numbers[5] = {1,2,3,4,5};
#
#   // TODO: call showValues
#
#   return 0;
# }
# // function definition
# // TODO: write the function definition showValues
#   // TODO: print all array elements with a loop

# %%
# !g++ -std=c++17 part4.cpp -o part4
# !./part4

# %% [markdown]
# ## Part 5 — Pointer arithmetic with a C-string
#
# **Task**
#
# Write a program that:
#
# 1. declares a C-style string `"To be, or not to be."` as a pointer-to-character `hamlet`.
# 2. prints the first character of the string using the pointer.
# 3. prints the third character using a dereferenced pointer to the third element of the string.
# 4. uses a pointer variable `p` and a `while` loop to print the whole string one character at a time.
#
# **Tip:** The `while` loop condition tests if the end of the string has been reached or not.

# %%
# %%writefile part5.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   // TODO: define a C-style string
#
#   // TODO:
#   // 1. print first character
#   // 2. print third character
#   // 3. declare pointer p
#   // 4. use while loop to print whole string
#
#   return 0;
# }

# %%
# !g++ -std=c++17 part5.cpp -o part6
# !./part6

# %% [markdown]
# ## Part 6 — Re-pointing a pointer
#
# **Task**
#
# Write a program that:
#
# 1. declares two integers `x = 42` and `y = 50`
# 2. declares one integer pointer `ptr` and initializes it.
# 3. makes `ptr` point to `x` and adds 100 to `x` through the pointer
# 4. then makes `ptr` point to `y` and adds 100 to `y` through the pointer
# 5. prints the final values of `x` and `y`
#
# **Target idea:** the pointer changes its target; the variables keep their own storage.

# %%
# %%writefile part6.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   int x = 25, y = 50;
#
#   // TODO:
#   // 1. declare ptr and initialize with nullptr
#   // 2. point to x and add 100 through ptr
#   // 3. point to y and add 100 through ptr
#   // 4. print x and y
#
#   return 0;
# }

# %%
# !g++ -std=c++17 part6.cpp -o part7
# !./part7

# %% [markdown]
# ## Part 7 — Reference vs pointer in working code
#
# **Task**
#
# Write one program that shows both a reference and a pointer working with the same variable.
#
# Required steps:
#
# 1. declare `int x = 10;`
# 2. declare a reference `ref` to `x`
# 3. declare a pointer `ptr` to `x`
# 4. change `x` to `20` through `ref`
# 5. then change `x` to `30` through `ptr`
# 6. print `x`, `ref`, and the dereferenced pointer
#
# **Target idea:** both can affect the same original variable, but they are declared and used differently.

# %%
# %%writefile part7.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#   int x = 10;
#
#   // TODO:
#   // 1. declare reference ref to x
#   // 2. declare pointer ptr to x
#   // 3. change x to 20 through ref
#   // 4. change x to 30 through ptr
#   // 5. print x, ref, and *ptr
#
#   return 0;
# }

# %%
# !g++ -std=c++17 part7.cpp -o part8
# !./part8

# %% [markdown]
# ## Submission checklist
#
# Before you submit your Colab URL, check that:
#
# - every `partN.cpp` file compiles
# - every part runs without crashing
# - your final notebook contains your completed code
# - the notebook is shared so it can be opened for grading
#
# If you finish early, review your code and make sure you can explain what each `&` and `*` is doing.
