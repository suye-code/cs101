# %% [markdown]
# <a href="https://colab.research.google.com/github/suye-code/cs101/blob/main/CS101_hw_2026_04_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Purpose and approach
#
# This is a `Text` cell.
#
# This file demonstrates the use of coding notebooks when programming. The example is very simple but the execution is the same for small or large programs.
#
# For other languages than Python, R or Julia, the notebook is not interactive: You need to use the `%%writefile` directive to write a file (like `hello.c`).
#
# You can then compile `hello.c` either in the notebook (in a code cell) using the `!` prefix before a command-line command like `gcc`, or open the `Terminal` to manually compile the program.
#
# The compilation results in an executable `a.out`. Again, you can either run it in the notebook, or on the command-line.
#
# The main advantage of doing everything in code cells is that you see the output in the notebook.
#
# This enables you to code for humans and, ideally, submit a program like a readable report. It's called ["literate programming"](http://literateprogramming.com).

# %% [markdown]
# # Programming in C++

# %% [markdown]
# ## Writing the source code
#
# Apart from the "magic" command in the first line, this is the old hello world program that you already know.
#
# A downside: no syntax highlighting.

# %%
# %%writefile hello.cpp
# #include <iostream>
# using namespace std;
#
# int main()
# {
# cout << "Hello world\n" <<endl;
#     return 0;
# }
# Out:
# Writing hello.cpp

# %% [markdown]
# You should now see `hello.cpp` if you open the file explorer in the left sidebar.
#
# Or you could check it with the `ls` Linux command right here in the notebook:

# %%
# !ls -l hello.cpp # `-l` means "give me all the available information"
# Out:
# -rw-r--r-- 1 root root 104 Apr 17 21:53 hello.cpp

# %% [markdown]
# ## Compiling the source code
#
# Compilation is done with the built-in `gcc` compiler. To check that the program is actually available, you can use the `which` Linux command, and/or check the compiler version:

# %% [markdown]
# Now compile the file `hello.c` inline, and then check that the executable, `a.out`, exists.

# %%
# !g++ hello.cpp # compiles - should not give errors or warnings

# %% [markdown]
# Check for the executable (the compiler output):

# %% [markdown]
# ## Run the executable
#
# To run the executable here in the notebook, the same rule applies as in the terminal: without being told where the file is, it cannot be run. That's what the `.` before the program name is for.

# %%
# !./a.out
# Out:
# Hello world

# %% [markdown]
# # Assignment for Program 9

# %% [markdown]
# Design a class that works with this main program:
#
# int main() {
#   Car c{"Mustang", 50, 0};
#   c.status();
#   c.accelerate(20);
#   c.drive(30);
#   c.brake(10);
#   c.refuel(15);
#   c.status();
# }
# and produces this output:
#
# Mustang Speed=0 Fuel=50km Range=0km.
# Mustang Speed=10 Fuel=35km Range=30km.
# Requirements
# Data: model (string), fuel, speed, distance (all int).
# Methods:
# status() — return a string summary like the example.
# accelerate(int) — increase speed, reduce fuel.
# brake(int) — decrease speed (not below 0).
# drive(int) — increase distance, reduce fuel.
# refuel(int) — increase fuel.
# Submission
# Submit the URL to your OneCompiler.com solution showing the exact sample output.
#
# You will get a sample solution after submitting your solution.
#
# https://canvas.instructure.com/courses/13978549/assignments/63932485

# %%
int main() {
  Car c{"Mustang", 50, 0};
  c.status();
  c.accelerate(20);
  c.drive(30);
  c.brake(10);
  c.refuel(15);
  c.status();
}

# %%
// target output
Mustang Speed=0 Fuel=50km Range=0km.
Mustang Speed=10 Fuel=35km Range=30km.

# %% [markdown]
# # Hello world program in C
# https://colab.research.google.com/drive/1G4vNn_Xozct2tEylg761VBTtppWpcg7o?usp=sharing#scrollTo=YQhnAjlrb7ot
# Originally from CS 101 birkenkrahe

# %% [markdown]
# ## Running code in JAVA
# Setting up JAVA programming environment

# %%
# %%writefile Main.java
# public class Main {
#   public static void main (String[] args){
#     System.out.println("Hello its java.");
#   }
# }
# Out:
# Overwriting Main.java

# %% [markdown]
# Compile java with javac

# %%
# !javac Main.java

# %% [markdown]
# List the correct root file

# %%
# !ls -l *.class
# Out:
# -rw-r--r-- 1 root root 417 Apr 14 22:31 Main.class

# %% [markdown]
# Run the file

# %%
# !java Main
# Out:
# Hello its java.

# %% [markdown]
# ## Writing the source code
#
# Apart from the "magic" command in the first line, this is the old hello world program that you already know.
#
# A downside: no syntax highlighting.

# %%
# %%writefile hello.c
# #include <stdio.h>
# int main()
# {
#     printf("Hello world\n");
#     return 0;
# }
# Out:
# Writing hello.c

# %% [markdown]
# You should now see `hello.c` if you open the file explorer in the left sidebar.
#
# Or you could check it with the `ls` Linux command right here in the notebook:

# %%
# !ls -l hello.c # `-l` means "give me all the available information"
# Out:
# ls: cannot access 'hello.c': No such file or directory

# %% [markdown]
# ## Compiling the source code
#
# Compilation is done with the built-in `gcc` compiler. To check that the program is actually available, you can use the `which` Linux command, and/or check the compiler version:

# %%
# !which gcc   # check which gcc is being used
# Out:
# /usr/bin/gcc

# %%
# !gcc --version  # checks the version of the compiler program
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04.2) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %% [markdown]
# Now compile the file `hello.c` inline, and then check that the executable, `a.out`, exists.

# %%
# !gcc hello.c # compiles - should not give errors or warnings

# %% [markdown]
# Check for the executable (the compiler output):

# %%
# !ls -l a.out
# Out:
# -rwxr-xr-x 1 root root 15960 Feb 12 15:22 a.out

# %% [markdown]
# ## Run the executable
#
# To run the executable here in the notebook, the same rule applies as in the terminal: without being told where the file is, it cannot be run. That's what the `.` before the program name is for.

# %%
# !./a.out
# Out:
# Hello world

# %% [markdown]
# ## Next steps
#
# We're done. Now create your own notebook:
#
# - Write down what you intend to do (your plan for the program).
# - Keep mistakes in the notebook to document your learning process.
# - Make use of the available tools, including the external `Terminal`, and the AI assistance through Gemini (which I find to be very slow though).
#
# You don't need to save this program - it's auto-saved to your school's Google Drive in a separate folder clearly marked as `Colab notebooks`.
